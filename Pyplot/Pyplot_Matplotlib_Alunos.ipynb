# %% [markdown]
# # Pyplot com Matplotlib — Lista de Exercícios
#
# Preencha as células de código seguindo as instruções de cada exercício.
# Execute as células em ordem (Runtime > Run all) conforme for completando.
# Bom estudo!

# %%
# Execute esta célula primeiro para carregar as bibliotecas
import matplotlib.pyplot as plt
import numpy as np

print('Bibliotecas carregadas!')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Execute esta célula primeiro para carregar as bibliotecas
# ----> 2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4
#       5 print('Bibliotecas carregadas!')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## Seção 1 — Gráfico de linhas (plot)
#
# ### Exercício 1.1 (básico)
# Crie um gráfico de linhas com a temperatura média de uma semana:
# - Dias: Seg, Ter, Qua, Qui, Sex, Sáb, Dom
# - Temperaturas: 22, 24, 21, 23, 26, 28, 25
#
# Requisitos: marcadores nos pontos, título, rótulos nos eixos e grid.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 1.2 (avançado)
# Plote duas séries no mesmo gráfico:
# - Produto A: [100, 120, 140, 130, 170, 200]
# - Produto B: [180, 170, 160, 150, 140, 130]
#
# Use cores e estilos de linha diferentes, adicione legenda e escreva abaixo qual produto apresenta melhor tendência.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (1.2):**

# %% [markdown]
# ## Seção 2 — Gráfico de barras (bar / barh)
#
# ### Exercício 2.1 (básico)
# Crie um gráfico de barras verticais com a população estimada de 5 cidades:
# - Cidades: Cidade A, Cidade B, Cidade C, Cidade D, Cidade E
# - População (milhares): 120, 350, 210, 580, 420
#
# Use cor personalizada (ex.: teal) e borda preta nas barras.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 2.2 (avançado)
# Você tem 8 departamentos com nomes longos:
# - Recursos Humanos e Talentos
# - Controladoria e Finanças Corporativas
# - Pesquisa, Desenvolvimento e Inovação
# - Tecnologia da Informação e Infraestrutura
# - Marketing Estratégico e Comunicação
# - Operações Industriais e Logística
# - Atendimento ao Cliente e Suporte
# - Jurídico e Governança Corporativa
#
# Crie o gráfico com plt.bar() e depois com plt.barh() em subplots lado a lado. Justifique abaixo por que a versão horizontal é mais legível.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (2.2):**

# %% [markdown]
# ## Seção 3 — Dispersão (scatter)
#
# ### Exercício 3.1 (básico)
# Construa um gráfico de dispersão relacionando horas de estudo e nota obtida:
# - Tempo de estudo: [1, 2, 3.5, 4, 5.5, 6, 7.5, 8, 9, 10]
# - Nota obtida: [3.0, 4.0, 5.5, 5.0, 6.8, 7.2, 8.0, 7.8, 9.2, 9.5]
#
# Use pontos destacados (s=60) com transparência (alpha=0.7).

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 3.2 (avançado)
# Gere dois conjuntos de 100 pontos com numpy:
# - Conjunto 1: Y = 2 * X + ruído normal
# - Conjunto 2: X e Y independentes e aleatórios
#
# Plote os dois em subplots lado a lado e escreva abaixo qual conjunto mostra correlação positiva e qual mostra correlação nula.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (3.2):**

# %% [markdown]
# ## Seção 4 — Histograma (hist)
#
# ### Exercício 4.1 (básico)
# Dada a lista de notas de uma turma:
# notas = [4.0, 4.5, 5.0, 5.0, 5.5, 5.8, 6.0, 6.0, 6.2, 6.5, 6.8, 7.0, 7.0, 7.2, 7.5, 7.8, 8.0, 8.0, 8.2, 8.5, 8.8, 9.0, 9.2, 9.5, 10.0]
#
# Crie dois histogramas: um com bins=4 e outro com bins=10. Descreva abaixo como a percepção da distribuição muda.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (4.1):**

# %% [markdown]
# ### Exercício 4.2 (avançado)
# Use a mesma lista de notas do exercício anterior e adicione um valor atípico (20.0).
#
# Plote um histograma e um boxplot lado a lado dos mesmos dados. Explique abaixo como cada gráfico trata o outlier.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (4.2):**

# %% [markdown]
# ## Seção 5 — Gráfico de setores (pie)
#
# ### Exercício 5.1 (básico)
# Crie um gráfico de pizza com a distribuição do orçamento anual:
# - Engenharia: 40%
# - Vendas e Marketing: 25%
# - Suporte ao Cliente: 20%
# - Administrativo: 15%
#
# Formate os percentuais com uma casa decimal (autopct) e use startangle=90.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 5.2 (avançado)
# Suponha que você precise representar as vendas de 12 filiais, com participações entre 3% e 12% cada.
#
# Explique abaixo por que o gráfico de pizza é inadequado nesse caso e gere a alternativa ideal usando plt.barh() com as filiais ordenadas.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (5.2):**

# %% [markdown]
# ## Seção 6 — Boxplot
#
# ### Exercício 6.1 (básico)
# Dada a série: [12, 14, 15, 15, 16, 17, 18, 19, 19, 20, 22, 24, 38]
#
# Calcule com numpy o Q1, a mediana e o Q3. Construa o boxplot e identifique abaixo qual valor é outlier (use a regra Q3 + 1.5 * IQR).

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (6.1):**

# %% [markdown]
# ### Exercício 6.2 (avançado)
# Gere com numpy os tempos de resposta (ms) de 3 serviços:
# - Alfa: média 100, desvio baixo
# - Beta: média 120, amplitude interquartil muito estreita
# - Gama: média 95, porém com longa cauda superior e múltiplos outliers
#
# Crie os três boxplots lado a lado e responda abaixo qual serviço é o mais previsível operacionalmente.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (6.2):**

# %% [markdown]
# ## Seção 7 — Barras de erro (errorbar)
#
# ### Exercício 7.1 (básico)
# Um ensaio químico mediu o rendimento de 4 formulações:
# - Médias: [78.5, 84.2, 91.0, 72.3]
# - Desvios padrão: [3.2, 2.5, 4.1, 1.9]
#
# Construa o gráfico com plt.errorbar(), usando marcadores circulares, linhas de conexão e capsize=6.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 7.2 (avançado)
# Ao comparar dois grupos cujas barras de erro (intervalo de confiança) se sobrepõem bastante, é correto afirmar que não há diferença significativa entre as médias? Justifique.

# %% [markdown]
# **Sua resposta (7.2):**

# %% [markdown]
# ## Seção 8 — Violino (violinplot)
#
# ### Exercício 8.1 (básico)
# Compare os salários de entrada de dois setores:
# - Operacional: [2200, 2300, 2400, 2500, 2550, 2600, 2700, 2800]
# - Tecnologia: [3500, 3800, 4200, 4500, 5000, 5200, 6000, 7500]
#
# Use plt.violinplot() exibindo média e mediana (showmeans e showmedians).

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 8.2 (avançado)
# Crie uma distribuição bimodal juntando duas normais com médias distintas (ex.: 30 e 70).
#
# Plote o boxplot e o violino dos mesmos dados lado a lado e explique abaixo por que o violino revela a bimodalidade que o boxplot mascara.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (8.2):**

# %% [markdown]
# ## Seção 9 — Área (fill_between)
#
# ### Exercício 9.1 (básico)
# Plote a produção de uma fábrica ao longo de 12 meses:
# - Meses: range(1, 13)
# - Produção: [50, 52, 55, 60, 65, 70, 68, 72, 78, 85, 90, 95]
#
# Desenhe a linha e preencha a área entre a linha e o eixo zero com cor azulada e alpha=0.4.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 9.2 (avançado)
# Simule a projeção de faturamento de uma startup com faixa de incerteza:
# - Média: [100, 115, 130, 150, 175]
# - Limite inferior: [90, 100, 110, 125, 140]
# - Limite superior: [110, 130, 150, 175, 210]
#
# Use plt.fill_between() para preencher a região entre os limites. Explique abaixo como esse recurso apoia decisões sob risco.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (9.2):**

# %% [markdown]
# ## Seção 10 — Área empilhada (stackplot)
#
# ### Exercício 10.1 (básico)
# Ilustre a geração de energia (MW) de uma microrregião ao longo de 6 meses:
# - Solar: [20, 25, 30, 35, 45, 50]
# - Eólica: [40, 45, 40, 50, 55, 60]
# - Hidrelétrica: [100, 95, 90, 85, 80, 75]
#
# Use plt.stackplot() com legendas e cores distintas para cada fonte.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 10.2 (avançado)
# Com base no gráfico do exercício anterior, analise a participação relativa das fontes intermitentes (solar + eólica) frente à hidrelétrica ao longo do semestre.

# %% [markdown]
# **Sua resposta (10.2):**

# %% [markdown]
# ## Seção 11 — Mapa de calor (imshow)
#
# ### Exercício 11.1 (básico)
# Gere uma matriz 4x4 com np.random.rand(4, 4) e exiba-a como mapa de calor com plt.imshow().
#
# Use cmap='magma', adicione uma barra de cores e rótulos nos eixos de 0 a 3.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 11.2 (avançado)
# Explique as duas funções do imshow():
# 1. Como mapa de calor na análise de dados estatísticos (correlações, tabelas de contingência).
# 2. Como base para processamento de imagens e visão computacional (pixels, canais RGB).

# %% [markdown]
# **Sua resposta (11.2):**

# %% [markdown]
# ## Seção 12 — Contorno (contour / contourf)
#
# ### Exercício 12.1 (básico)
# Construa uma malha com np.meshgrid no intervalo de -2 a 2 e plote os contornos da função sela Z = X**2 - Y**2.
#
# Use plt.contour() com 15 níveis e a paleta coolwarm.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 12.2 (avançado)
# Em um gráfico de contorno, o que significa uma região onde as linhas de nível estão muito próximas umas das outras, em comparação com uma região onde estão muito espaçadas?

# %% [markdown]
# **Sua resposta (12.2):**

# %% [markdown]
# ## Seção 13 — Gráficos 3D
#
# ### Exercício 13.1 (básico)
# Crie um eixo com projection='3d' e renderize a superfície Z = sin(X) * cos(Y) no domínio de -3 a 3, usando ax.plot_surface() com a paleta plasma.

# %%
# Seu código aqui

# %% [markdown]
# ### Exercício 13.2 (avançado)
# Gere três vetores aleatórios com 150 elementos cada (X, Y, Z) e crie uma dispersão 3D com ax.scatter().
#
# Adicione rótulos nos três eixos e ajuste a perspectiva com ax.view_init(elev=20, azim=45).
# Explique por que não se deve usar plt.scatter() nesse contexto.

# %%
# Seu código aqui

# %% [markdown]
# **Sua resposta (13.2):**

# %% [markdown]
# ## Desafio Final Integrador
#
# Você é analista de dados de uma instituição acadêmica. Analise o desempenho de 3 turmas na disciplina:
#
# - Notas médias por avaliação (P1 a P4):
#   - Turma A: [6.5, 7.0, 6.8, 7.2]
#   - Turma B: [7.5, 7.8, 8.0, 8.2]
#   - Turma C: [5.0, 6.0, 6.5, 7.0]
# - Taxa de aprovação (%): A=72, B=88, C=64
# - Notas finais:
#   - Turma A: [5.0, 6.0, 6.5, 7.0, 7.0, 7.5, 8.0, 8.5, 9.0]
#   - Turma B: [7.0, 7.5, 7.5, 8.0, 8.0, 8.5, 8.5, 9.0, 9.5]
#   - Turma C: [3.0, 4.5, 5.5, 6.0, 6.5, 7.0, 7.5, 8.0, 9.5]
#
# Construa um painel com 3 subplots:
# 1. plot(): evolução da nota média por avaliação
# 2. bar(): taxa de aprovação por turma
# 3. boxplot(): distribuição das notas finais
#
# Siga a estrutura comum (dados, eixos, personalização, exibição) e escreva uma conclusão abaixo: qual turma teve melhor desempenho, qual foi mais consistente e qual apresentou notas atípicas.

# %%
# Seu código aqui

# %% [markdown]
# **Conclusão do desafio:**
